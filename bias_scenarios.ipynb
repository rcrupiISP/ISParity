# %%
from utils import *

# %% [markdown]
# # Scenarios

# %% [markdown]
# ## S1 - no historical bias

# %%
# no additional bias
param_dict = {"dim":100000, "l_y":0, "l_m_y":0, "thr_supp":1, "l_h_r":0,  "l_h_q":0,
              "l_m":0, "p_u":1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 0, 'l_h_q': 0, 'l_m': 0, 'p_u': 1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            R         Q         A         Y
# R  1.000000 -0.002790 -0.001676  0.635310
# Q -0.002790  1.000000  0.001225 -0.298573
# A -0.001676  0.001225  1.000000  0.002482
# Y  0.635310 -0.298573  0.002482  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                       Y    Y True Unmitigated        FTU  \
# Demographic parity difference  0.210188  0.210188    0.094284   0.075239
# ACC score                         100.0     100.0   86.372727  86.421212
# ACC score difference                0.0       0.0    0.134439   0.146577
#
#                                       DP
# Demographic parity difference   0.038963
# ACC score                      86.384848
# ACC score difference            0.110201

# %%
# measurment on R
param_dict = {"dim":100000, "l_y":0, "l_m_y":0, "thr_supp":1, "l_h_r":0,  "l_h_q":0,
              "l_m":1, "p_u":1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 0, 'l_h_q': 0, 'l_m': 1, 'p_u': 1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# Correlation between R and P:  [[1.         0.89928525]
#  [0.89928525 1.        ]]
# The correlation matrix is:
#            P         Q         A         Y
# P  1.000000  0.000310 -0.108182  0.570987
# Q  0.000310  1.000000  0.001225 -0.298573
# A -0.108182  0.001225  1.000000  0.002482
# Y  0.570987 -0.298573  0.002482  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                       Y    Y True Unmitigated        FTU  \
# Demographic parity difference  0.210188  0.210188     0.77221   7.414714
# ACC score                         100.0     100.0   81.160606  81.057576
# ACC score difference                0.0       0.0    0.484058   0.714324
#
#                                       DP
# Demographic parity difference   0.542702
# ACC score                      81.151515
# ACC score difference            0.502237

# %%
# omission
param_dict = {"dim":100000, "l_y":0, "l_m_y":0, "thr_supp":1, "l_h_r":0,  "l_h_q":0,
              "l_m":0, "p_u":1, "l_r":False, "l_o":True, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 0, 'l_h_q': 0, 'l_m': 0, 'p_u': 1, 'l_r': False, 'l_o': True, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            Q         A         Y
# Q  1.000000  0.001225 -0.298573
# A  0.001225  1.000000  0.002482
# Y -0.298573  0.002482  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                       Y    Y True Unmitigated        FTU  \
# Demographic parity difference  0.210188  0.210188    1.163635   1.163635
# ACC score                         100.0     100.0   62.766667  62.766667
# ACC score difference                0.0       0.0    0.368279   0.368279
#
#                                       DP
# Demographic parity difference   0.951568
# ACC score                      62.751515
# ACC score difference            0.410698

# %%
# sample
param_dict = {"dim":100000, "l_y":0, "l_m_y":0, "thr_supp":1, "l_h_r":0,  "l_h_q":0,
              "l_m":0, "p_u":0.1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 0, 'l_h_q': 0, 'l_m': 0, 'p_u': 0.1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            R         Q         A         Y
# R  1.000000 -0.007685 -0.001163  0.635270
# Q -0.007685  1.000000 -0.002525 -0.306182
# A -0.001163 -0.002525  1.000000 -0.000779
# Y  0.635270 -0.306182 -0.000779  1.000000
#  The value counts is:
#  0    33493
# 1     3350
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                       Y    Y True Unmitigated        FTU  \
# Demographic parity difference  1.940033  1.940033    0.703916    0.57056
# ACC score                         100.0     100.0   86.268459  86.296011
# ACC score difference                0.0       0.0    1.961994   1.792298
#
#                                       DP
# Demographic parity difference    0.35842
# ACC score                      86.307031
# ACC score difference            2.004423

# %%
# measurement bias on Y (P_Y as target). Performance are calculated on Y
param_dict = {"dim":100000, "l_y":0, "l_m_y":1.5, "thr_supp":1, "l_h_r":0,  "l_h_q":0,
              "l_m":0, "p_u":1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict, y_bias_meas=True)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 1.5, 'thr_supp': 1, 'l_h_r': 0, 'l_h_q': 0, 'l_m': 0, 'p_u': 1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#                 R         Q         A         Y    Y_real
# R       1.000000 -0.002790 -0.001676  0.628497  0.603973
# Q      -0.002790  1.000000  0.001225 -0.291867 -0.313287
# A      -0.001676  0.001225  1.000000 -0.122700  0.002057
# Y       0.628497 -0.291867 -0.122700  1.000000  0.882952
# Y_real  0.603973 -0.313287  0.002057  0.882952  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                        Y    Y True Unmitigated        FTU  \
# Demographic parity difference  12.943638  0.194441    11.22728   0.105574
# ACC score                      93.624242     100.0   83.342424  84.457576
# ACC score difference           12.749197       0.0    4.012125   0.048894
#
#                                       DP
# Demographic parity difference   0.027654
# ACC score                      84.324242
# ACC score difference            0.012482

# %%
# representation bias
param_dict = {"dim":100000, "l_y":0, "l_m_y":0, "thr_supp":1, "l_h_r":0,  "l_h_q":0,
              "l_m":0, "p_u":0.1, "l_r":True, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 0, 'l_h_q': 0, 'l_m': 0, 'p_u': 0.1, 'l_r': True, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            R         Q         A         Y
# R  1.000000 -0.005347 -0.332019  0.639318
# Q -0.005347  1.000000  0.001442 -0.299489
# A -0.332019  0.001442  1.000000 -0.250970
# Y  0.639318 -0.299489 -0.250970  1.000000
#  The value counts is:
#  0    33493
# 1     3350
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Can t mitigate with CDP.
# Report output.
#
# problem in:  Demographic parity difference
# problem in:  Demographic parity ratio
# problem in:  Equalized odds ratio
# problem in:  Equalized odds difference
# problem in:  ACC score
# problem in:  F1 score
# problem in:  Precision
# problem in:  Recall
# problem in:  ACC score difference
# problem in:  F1 score difference
# problem in:  Flip
# problem in:  Flip
# problem in:  Mutual information A, y_pred
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  44.187733  44.187733   45.205494  45.429749
# ACC score                          100.0      100.0     86.7203  86.747851
# ACC score difference                 0.0        0.0    9.407774   9.510802
#
#                                       DP
# Demographic parity difference   0.587281
# ACC score                       83.41415
# ACC score difference           26.022519

# %% [markdown]
# ## S2 - historical bias compensation

# %%
# no additional bias
param_dict = {"dim":100000, "l_y":0, "l_m_y":0, "thr_supp":1, "l_h_r":1.5,  "l_h_q":-1,
              "l_m":0, "p_u":1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': -1, 'l_m': 0, 'p_u': 1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            R         Q         A         Y
# R  1.000000  0.065214 -0.174944  0.633145
# Q  0.065214  1.000000 -0.391901 -0.252705
# A -0.174944 -0.391901  1.000000 -0.008692
# Y  0.633145 -0.252705 -0.008692  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                      Y   Y True Unmitigated        FTU  \
# Demographic parity difference  1.38592  1.38592    0.123829   0.833859
# ACC score                        100.0    100.0   86.342424  86.451515
# ACC score difference               0.0      0.0    0.049579   0.073861
#
#                                       DP
# Demographic parity difference   0.343013
# ACC score                      86.387879
# ACC score difference            0.017071

# %%
# measurment on R
param_dict = {"dim":100000, "l_y":0, "l_m_y":0, "thr_supp":1, "l_h_r":1.5,  "l_h_q":-1,
              "l_m":1, "p_u":1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': -1, 'l_m': 1, 'p_u': 1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# Correlation between R and P:  [[1.         0.90538424]
#  [0.90538424 1.        ]]
# The correlation matrix is:
#            P         Q         A         Y
# P  1.000000  0.100867 -0.259059  0.562825
# Q  0.100867  1.000000 -0.391901 -0.252705
# A -0.259059 -0.391901  1.000000 -0.008692
# Y  0.562825 -0.252705 -0.008692  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                      Y   Y True Unmitigated        FTU  \
# Demographic parity difference  1.38592  1.38592    2.166053   5.590341
# ACC score                        100.0    100.0   81.118182  81.090909
# ACC score difference               0.0      0.0    0.399195   0.708276
#
#                                       DP
# Demographic parity difference   0.942543
# ACC score                      81.066667
# ACC score difference            0.308267

# %%
# omission
param_dict = {"dim":100000, "l_y":0, "l_m_y":0, "thr_supp":1, "l_h_r":1.5,  "l_h_q":-1,
              "l_m":0, "p_u":1, "l_r":False, "l_o":True, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': -1, 'l_m': 0, 'p_u': 1, 'l_r': False, 'l_o': True, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            Q         A         Y
# Q  1.000000 -0.391901 -0.252705
# A -0.391901  1.000000 -0.008692
# Y -0.252705 -0.008692  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                      Y   Y True Unmitigated        FTU  \
# Demographic parity difference  1.38592  1.38592    9.791949  27.093546
# ACC score                        100.0    100.0        62.7  61.587879
# ACC score difference               0.0      0.0    0.659164   1.565483
#
#                                       DP
# Demographic parity difference   0.937277
# ACC score                      62.354545
# ACC score difference             0.01975

# %%
# sample
param_dict = {"dim":100000, "l_y":0, "l_m_y":0, "thr_supp":1, "l_h_r":1.5,  "l_h_q":-1,
              "l_m":0, "p_u":0.1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': -1, 'l_m': 0, 'p_u': 0.1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            R         Q         A         Y
# R  1.000000  0.016263 -0.101782  0.632553
# Q  0.016263  1.000000 -0.227652 -0.294001
# A -0.101782 -0.227652  1.000000 -0.003284
# Y  0.632553 -0.294001 -0.003284  1.000000
#  The value counts is:
#  0    33493
# 1     3350
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                       Y    Y True Unmitigated       FTU  \
# Demographic parity difference  0.952145  0.952145    1.611251  0.726413
# ACC score                         100.0     100.0    86.27948   86.2905
# ACC score difference                0.0       0.0     1.37411  1.519567
#
#                                       DP
# Demographic parity difference   0.588721
# ACC score                      86.362134
# ACC score difference             1.19836

# %%
# measurement bias on Y (P_Y as target). Performance are calculated on Y
param_dict = {"dim":100000, "l_y":0, "l_m_y":1.5, "thr_supp":1, "l_h_r":1.5,  "l_h_q":-1,
              "l_m":0, "p_u":1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict, y_bias_meas=True)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 1.5, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': -1, 'l_m': 0, 'p_u': 1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#                 R         Q         A         Y    Y_real
# R       1.000000  0.065214 -0.174944  0.645688  0.602124
# Q       0.065214  1.000000 -0.391901 -0.197834 -0.266431
# A      -0.174944 -0.391901  1.000000 -0.132825 -0.005467
# Y       0.645688 -0.197834 -0.132825  1.000000  0.880709
# Y_real  0.602124 -0.266431 -0.005467  0.880709  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                        Y    Y True Unmitigated       FTU  \
# Demographic parity difference  14.307192  1.291376   11.512405    3.8701
# ACC score                      93.490909     100.0   83.693939      84.2
# ACC score difference           13.015815       0.0    3.381949  0.721527
#
#                                       DP
# Demographic parity difference   0.439987
# ACC score                      84.593939
# ACC score difference            0.466208

# %%
# representation bias
param_dict = {"dim":100000, "l_y":0, "l_m_y":0, "thr_supp":1, "l_h_r":1.5,  "l_h_q":-1,
              "l_m":0, "p_u":0.1, "l_r":True, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': -1, 'l_m': 0, 'p_u': 0.1, 'l_r': True, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            R         Q         A         Y
# R  1.000000  0.088878 -0.416227  0.645537
# Q  0.088878  1.000000 -0.224779 -0.227457
# A -0.416227 -0.224779  1.000000 -0.263621
# Y  0.645537 -0.227457 -0.263621  1.000000
#  The value counts is:
#  0    33493
# 1     3350
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Can t mitigate with CDP.
# Report output.
#
# problem in:  Demographic parity difference
# problem in:  Demographic parity ratio
# problem in:  Equalized odds ratio
# problem in:  Equalized odds difference
# problem in:  ACC score
# problem in:  F1 score
# problem in:  Precision
# problem in:  Recall
# problem in:  ACC score difference
# problem in:  F1 score difference
# problem in:  Flip
# problem in:  Flip
# problem in:  Mutual information A, y_pred
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  45.721075  45.721075   45.272154   45.43581
# ACC score                          100.0      100.0   86.819484  86.847035
# ACC score difference                 0.0        0.0   11.032022  11.001716
#
#                                       DP
# Demographic parity difference   1.843118
# ACC score                      83.144148
# ACC score difference            29.39222

# %% [markdown]
# ## S3 - Historical bias on R

# %%
# no additional bias
param_dict = {"dim":100000, "l_y":0, "l_m_y":0, "thr_supp":1, "l_h_r":1.5,  "l_h_q":0,
              "l_m":0, "p_u":1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': 0, 'l_m': 0, 'p_u': 1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            R         Q         A         Y
# R  1.000000 -0.002959 -0.174944  0.640068
# Q -0.002959  1.000000  0.001225 -0.291867
# A -0.174944  0.001225  1.000000 -0.122700
# Y  0.640068 -0.291867 -0.122700  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  12.943638  12.943638   12.560752  12.948759
# ACC score                          100.0      100.0   86.657576  86.621212
# ACC score difference                 0.0        0.0    2.168488   2.095774
#
#                                       DP
# Demographic parity difference   0.015566
# ACC score                      85.542424
# ACC score difference            2.253742

# %%
# measurment on R
param_dict = {"dim":100000, "l_y":0, "l_m_y":0, "thr_supp":1, "l_h_r":1.5,  "l_h_q":0,
              "l_m":1, "p_u":1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': 0, 'l_m': 1, 'p_u': 1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# Correlation between R and P:  [[1.         0.90538424]
#  [0.90538424 1.        ]]
# The correlation matrix is:
#            P         Q         A         Y
# P  1.000000  0.000113 -0.259059  0.580852
# Q  0.000113  1.000000  0.001225 -0.291867
# A -0.259059  0.001225  1.000000 -0.122700
# Y  0.580852 -0.291867 -0.122700  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  12.943638  12.943638   11.814556  19.069283
# ACC score                          100.0      100.0   81.484848  81.360606
# ACC score difference                 0.0        0.0    2.491581   2.182536
#
#                                       DP
# Demographic parity difference   0.687892
# ACC score                      80.627273
# ACC score difference            2.340378

# %%
# omission
param_dict = {"dim":100000, "l_y":0, "l_m_y":0, "thr_supp":1, "l_h_r":1.5,  "l_h_q":0,
              "l_m":0, "p_u":1, "l_r":False, "l_o":True, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': 0, 'l_m': 0, 'p_u': 1, 'l_r': False, 'l_o': True, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            Q         A         Y
# Q  1.000000  0.001225 -0.291867
# A  0.001225  1.000000 -0.122700
# Y -0.291867 -0.122700  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  12.943638  12.943638   36.690088   1.163635
# ACC score                          100.0      100.0   64.548485  62.624242
# ACC score difference                 0.0        0.0    1.291679   2.556106
#
#                                       DP
# Demographic parity difference   0.951568
# ACC score                      62.615152
# ACC score difference            2.562163

# %%
# sample
param_dict = {"dim":100000, "l_y":0, "l_m_y":0, "thr_supp":1, "l_h_r":1.5,  "l_h_q":0,
              "l_m":0, "p_u":0.1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': 0, 'l_m': 0, 'p_u': 0.1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            R         Q         A         Y
# R  1.000000 -0.007392 -0.101782  0.635198
# Q -0.007392  1.000000 -0.002525 -0.305691
# A -0.101782 -0.002525  1.000000 -0.066942
# Y  0.635198 -0.305691 -0.066942  1.000000
#  The value counts is:
#  0    33493
# 1     3350
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                       Y    Y True Unmitigated        FTU  \
# Demographic parity difference  9.908602  9.908602   11.199183  10.253739
# ACC score                         100.0     100.0   86.362134  86.345603
# ACC score difference                0.0       0.0    0.868329   0.953181
#
#                                       DP
# Demographic parity difference   0.047646
# ACC score                      86.180295
# ACC score difference            1.265005

# %%
# measurement bias on Y (P_Y as target). Performance are calculated on Y
param_dict = {"dim":100000, "l_y":0, "l_m_y":1.5, "thr_supp":1, "l_h_r":1.5,  "l_h_q":0,
              "l_m":0, "p_u":1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict, y_bias_meas=True)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 1.5, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': 0, 'l_m': 0, 'p_u': 1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#                 R         Q         A         Y    Y_real
# R       1.000000 -0.002959 -0.174944  0.637131  0.610068
# Q      -0.002959  1.000000  0.001225 -0.283430 -0.307326
# A      -0.174944  0.001225  1.000000 -0.244939 -0.128151
# Y       0.637131 -0.283430 -0.244939  1.000000  0.890457
# Y_real  0.610068 -0.307326 -0.128151  0.890457  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  24.798318  13.188308   25.064487  13.131121
# ACC score                      94.193939      100.0   84.036364  84.863636
# ACC score difference            11.61001        0.0    1.691165   1.502474
#
#                                       DP
# Demographic parity difference   0.129787
# ACC score                      83.681818
# ACC score difference            4.896843

# %%
# representation bias
param_dict = {"dim":100000, "l_y":0, "l_m_y":0, "thr_supp":1, "l_h_r":1.5,  "l_h_q":0,
              "l_m":0, "p_u":0.1, "l_r":True, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 0, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': 0, 'l_m': 0, 'p_u': 0.1, 'l_r': True, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            R         Q         A         Y
# R  1.000000 -0.005293 -0.416227  0.645785
# Q -0.005293  1.000000  0.001442 -0.291786
# A -0.416227  0.001442  1.000000 -0.277194
# Y  0.645785 -0.291786 -0.277194  1.000000
#  The value counts is:
#  0    33493
# 1     3350
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Can t mitigate with CDP.
# Report output.
#
# problem in:  Demographic parity difference
# problem in:  Demographic parity ratio
# problem in:  Equalized odds ratio
# problem in:  Equalized odds difference
# problem in:  ACC score
# problem in:  F1 score
# problem in:  Precision
# problem in:  Recall
# problem in:  ACC score difference
# problem in:  F1 score difference
# problem in:  Flip
# problem in:  Flip
# problem in:  Mutual information A, y_pred
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  48.612122  48.612122   45.575221  46.690508
# ACC score                          100.0      100.0   86.676218  86.841525
# ACC score difference                 0.0        0.0   13.122972  12.941132
#
#                                       DP
# Demographic parity difference   1.538714
# ACC score                      82.868636
# ACC score difference           27.422468

# %% [markdown]
# ## S4 - Historical bias on Y

# %%
# no additional bias
param_dict = {"dim":100000, "l_y":1.5, "l_m_y":0, "thr_supp":1, "l_h_r":0,  "l_h_q":0,
              "l_m":0, "p_u":1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 1.5, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 0, 'l_h_q': 0, 'l_m': 0, 'p_u': 1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            R         Q         A         Y
# R  1.000000 -0.002790 -0.001676  0.628497
# Q -0.002790  1.000000  0.001225 -0.291867
# A -0.001676  0.001225  1.000000 -0.122700
# Y  0.628497 -0.291867 -0.122700  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  12.943638  12.943638    11.22728   0.105574
# ACC score                          100.0      100.0        86.5  85.548485
# ACC score difference                 0.0        0.0    2.301879   2.132528
#
#                                       DP
# Demographic parity difference   0.027654
# ACC score                      85.518182
# ACC score difference            2.374963

# %%
# measurment on R
param_dict = {"dim":100000, "l_y":1.5, "l_m_y":0, "thr_supp":1, "l_h_r":0,  "l_h_q":0,
              "l_m":1, "p_u":1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 1.5, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 0, 'l_h_q': 0, 'l_m': 1, 'p_u': 1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# Correlation between R and P:  [[1.         0.89928525]
#  [0.89928525 1.        ]]
# The correlation matrix is:
#            P         Q         A         Y
# P  1.000000  0.000310 -0.108182  0.578410
# Q  0.000310  1.000000  0.001225 -0.291867
# A -0.108182  0.001225  1.000000 -0.122700
# Y  0.578410 -0.291867 -0.122700  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  12.943638  12.943638   10.911588   7.353967
# ACC score                          100.0      100.0        81.5  81.339394
# ACC score difference                 0.0        0.0    2.691576   2.855271
#
#                                       DP
# Demographic parity difference   0.590781
# ACC score                      80.639394
# ACC score difference            2.219162

# %%
# omission
param_dict = {"dim":100000, "l_y":1.5, "l_m_y":0, "thr_supp":1, "l_h_r":0,  "l_h_q":0,
              "l_m":0, "p_u":1, "l_r":False, "l_o":True, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 1.5, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 0, 'l_h_q': 0, 'l_m': 0, 'p_u': 1, 'l_r': False, 'l_o': True, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            Q         A         Y
# Q  1.000000  0.001225 -0.291867
# A  0.001225  1.000000 -0.122700
# Y -0.291867 -0.122700  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  12.943638  12.943638   36.690088   1.163635
# ACC score                          100.0      100.0   64.548485  62.624242
# ACC score difference                 0.0        0.0    1.291679   2.556106
#
#                                       DP
# Demographic parity difference   0.951568
# ACC score                      62.615152
# ACC score difference            2.562163

# %%
# sample
param_dict = {"dim":100000, "l_y":1.5, "l_m_y":0, "thr_supp":1, "l_h_r":0,  "l_h_q":0,
              "l_m":0, "p_u":0.1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 1.5, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 0, 'l_h_q': 0, 'l_m': 0, 'p_u': 0.1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            R         Q         A         Y
# R  1.000000 -0.007685 -0.001163  0.631742
# Q -0.007685  1.000000 -0.002525 -0.305691
# A -0.001163 -0.002525  1.000000 -0.066942
# Y  0.631742 -0.305691 -0.066942  1.000000
#  The value counts is:
#  0    33493
# 1     3350
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                       Y    Y True Unmitigated        FTU  \
# Demographic parity difference  9.908602  9.908602   10.665829   0.509931
# ACC score                         100.0     100.0   86.384175  86.141724
# ACC score difference                0.0       0.0    0.977419   1.555913
#
#                                       DP
# Demographic parity difference   0.067498
# ACC score                      86.158254
# ACC score difference            1.307428

# %%
# measurement bias on Y (P_Y as target). Performance are calculated on Y
param_dict = {"dim":100000, "l_y":1.5, "l_m_y":1.5, "thr_supp":1, "l_h_r":0,  "l_h_q":0,
              "l_m":0, "p_u":1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict, y_bias_meas=True)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 1.5, 'l_m_y': 1.5, 'thr_supp': 1, 'l_h_r': 0, 'l_h_q': 0, 'l_m': 0, 'p_u': 1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#                 R         Q         A         Y    Y_real
# R       1.000000 -0.002790 -0.001676  0.603998  0.597067
# Q      -0.002790  1.000000  0.001225 -0.283430 -0.307326
# A      -0.001676  0.001225  1.000000 -0.244939 -0.128151
# Y       0.603998 -0.283430 -0.244939  1.000000  0.890457
# Y_real  0.597067 -0.307326 -0.128151  0.890457  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  24.798318  13.188308   23.100961    0.19083
# ACC score                      94.193939      100.0   84.345455  83.493939
# ACC score difference            11.61001        0.0    1.073095   5.721154
#
#                                       DP
# Demographic parity difference   0.064428
# ACC score                      83.906061
# ACC score difference            4.654337

# %%
# representation bias
param_dict = {"dim":100000, "l_y":1.5, "l_m_y":0, "thr_supp":1, "l_h_r":0,  "l_h_q":0,
              "l_m":0, "p_u":0.1, "l_r":True, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 1.5, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 0, 'l_h_q': 0, 'l_m': 0, 'p_u': 0.1, 'l_r': True, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            R         Q         A         Y
# R  1.000000 -0.005347 -0.332019  0.642284
# Q -0.005347  1.000000  0.001442 -0.291786
# A -0.332019  0.001442  1.000000 -0.277194
# Y  0.642284 -0.291786 -0.277194  1.000000
#  The value counts is:
#  0    33493
# 1     3350
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Can t mitigate with CDP.
# Report output.
#
# problem in:  Demographic parity difference
# problem in:  Demographic parity ratio
# problem in:  Equalized odds ratio
# problem in:  Equalized odds difference
# problem in:  ACC score
# problem in:  F1 score
# problem in:  Precision
# problem in:  Recall
# problem in:  ACC score difference
# problem in:  F1 score difference
# problem in:  Flip
# problem in:  Flip
# problem in:  Mutual information A, y_pred
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  48.612122  48.612122   45.575221  46.720815
# ACC score                          100.0      100.0   86.676218  86.836015
# ACC score difference                 0.0        0.0   13.122972  12.947193
#
#                                       DP
# Demographic parity difference   1.544775
# ACC score                      82.808023
# ACC score difference           27.355793

# %% [markdown]
# ## S5 - historical bias on R and Y

# %%
# no additional bias
param_dict = {"dim":100000, "l_y":1.5, "l_m_y":0, "thr_supp":1, "l_h_r":1.5,  "l_h_q":0,
              "l_m":0, "p_u":1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 1.5, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': 0, 'l_m': 0, 'p_u': 1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            R         Q         A         Y
# R  1.000000 -0.002959 -0.174944  0.637131
# Q -0.002959  1.000000  0.001225 -0.283430
# A -0.174944  0.001225  1.000000 -0.244939
# Y  0.637131 -0.283430 -0.244939  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  24.798318  24.798318   25.064487  13.131121
# ACC score                          100.0      100.0   86.860606   86.00303
# ACC score difference                 0.0        0.0    3.956293   3.780848
#
#                                       DP
# Demographic parity difference   0.129787
# ACC score                      83.063636
# ACC score difference            3.660704

# %%
# measurment on R
param_dict = {"dim":100000, "l_y":1.5, "l_m_y":0, "thr_supp":1, "l_h_r":1.5,  "l_h_q":0,
              "l_m":1, "p_u":1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 1.5, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': 0, 'l_m': 1, 'p_u': 1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# Correlation between R and P:  [[1.         0.90538424]
#  [0.90538424 1.        ]]
# The correlation matrix is:
#            P         Q         A         Y
# P  1.000000  0.000113 -0.259059  0.590810
# Q  0.000113  1.000000  0.001225 -0.283430
# A -0.259059  0.001225  1.000000 -0.244939
# Y  0.590810 -0.283430 -0.244939  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  24.798318  24.798318   27.027517  18.772584
# ACC score                          100.0      100.0   82.030303  81.642424
# ACC score difference                 0.0        0.0    5.073201   5.036979
#
#                                       DP
# Demographic parity difference    0.63316
# ACC score                      78.660606
# ACC score difference            4.589578

# %%
# omission
param_dict = {"dim":100000, "l_y":1.5, "l_m_y":0, "thr_supp":1, "l_h_r":1.5,  "l_h_q":0,
              "l_m":0, "p_u":1, "l_r":False, "l_o":True, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 1.5, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': 0, 'l_m': 0, 'p_u': 1, 'l_r': False, 'l_o': True, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            Q         A         Y
# Q  1.000000  0.001225 -0.283430
# A  0.001225  1.000000 -0.244939
# Y -0.283430 -0.244939  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  24.798318  24.798318   36.690088   1.163635
# ACC score                          100.0      100.0   66.421212  62.054545
# ACC score difference                 0.0        0.0    4.660695    4.07105
#
#                                       DP
# Demographic parity difference   0.951568
# ACC score                      62.045455
# ACC score difference            4.077108

# %%
# sample
param_dict = {"dim":100000, "l_y":1.5, "l_m_y":0, "thr_supp":1, "l_h_r":1.5,  "l_h_q":0,
              "l_m":0, "p_u":0.1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 1.5, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': 0, 'l_m': 0, 'p_u': 0.1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            R         Q         A         Y
# R  1.000000 -0.007392 -0.101782  0.633864
# Q -0.007392  1.000000 -0.002525 -0.301842
# A -0.101782 -0.002525  1.000000 -0.124015
# Y  0.633864 -0.301842 -0.124015  1.000000
#  The value counts is:
#  0    33493
# 1     3350
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  20.642083  20.642083   19.156915  10.290136
# ACC score                          100.0      100.0   86.554992  86.334582
# ACC score difference                 0.0        0.0    4.189555   1.431975
#
#                                       DP
# Demographic parity difference   1.328073
# ACC score                      85.557637
# ACC score difference            6.513473

# %%
# measurement bias on Y (P_Y as target). Performance are calculated on Y
param_dict = {"dim":100000, "l_y":1.5, "l_m_y":1.5, "thr_supp":1, "l_h_r":1.5,  "l_h_q":0,
              "l_m":0, "p_u":1, "l_r":False, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict, y_bias_meas=True)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 1.5, 'l_m_y': 1.5, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': 0, 'l_m': 0, 'p_u': 1, 'l_r': False, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#                 R         Q         A         Y    Y_real
# R       1.000000 -0.002959 -0.174944  0.619543  0.611526
# Q      -0.002959  1.000000  0.001225 -0.270694 -0.293878
# A      -0.174944  0.001225  1.000000 -0.359151 -0.255519
# Y       0.619543 -0.270694 -0.359151  1.000000  0.902292
# Y_real  0.611526 -0.293878 -0.255519  0.902292  1.000000
#  The value counts is:
#  1    33506
# 0    33494
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Report output.
#
# problem in:  Flip
# problem in:  Flip
#                                        Y    Y True Unmitigated        FTU  \
# Demographic parity difference  36.822925  26.24909   37.392013  13.258432
# ACC score                      94.712121     100.0   84.609091  84.257576
# ACC score difference           10.573835       0.0    0.097434   6.605725
#
#                                       DP
# Demographic parity difference   0.105889
# ACC score                      81.181818
# ACC score difference           11.255328

# %%
# representation bias
param_dict = {"dim":100000, "l_y":1.5, "l_m_y":0, "thr_supp":1, "l_h_r":1.5,  "l_h_q":0,
              "l_m":0, "p_u":0.1, "l_r":True, "l_o":False, "l_y_b":0,
              "l_q":2, "sy":2, "l_r_q":0}
dtf_res = pipeline(param_dict)
# Select only DP diff, Accuracy, Accuracy difference for the models Unmitigated, FTU and DP postprocessed
dtf_res.loc[['Demographic parity difference', 'ACC score', 'ACC score difference'], ['Y', 'Y True', 'Unmitigated', 'FTU', 'DP']]*100
# Out:
# The parameters for data generetion are:  {'dim': 100000, 'l_y': 1.5, 'l_m_y': 0, 'thr_supp': 1, 'l_h_r': 1.5, 'l_h_q': 0, 'l_m': 0, 'p_u': 0.1, 'l_r': True, 'l_o': False, 'l_y_b': 0, 'l_q': 2, 'sy': 2, 'l_r_q': 0}
#
# Start creation dataset.
#
# The correlation matrix is:
#            R         Q         A         Y
# R  1.000000 -0.005293 -0.416227  0.644387
# Q -0.005293  1.000000  0.001442 -0.290510
# A -0.416227  0.001442  1.000000 -0.289102
# Y  0.644387 -0.290510 -0.289102  1.000000
#  The value counts is:
#  0    33493
# 1     3350
# Name: A, dtype: int64
#
# Fitting models.
#
# Mitigate models.
#
# Can t mitigate with CDP.
# Report output.
#
# problem in:  Demographic parity difference
# problem in:  Demographic parity ratio
# problem in:  Equalized odds ratio
# problem in:  Equalized odds difference
# problem in:  ACC score
# problem in:  F1 score
# problem in:  Precision
# problem in:  Recall
# problem in:  ACC score difference
# problem in:  F1 score difference
# problem in:  Flip
# problem in:  Flip
# problem in:  Mutual information A, y_pred
#                                        Y     Y True Unmitigated        FTU  \
# Demographic parity difference  50.721366  50.721366   46.993575  48.430113
# ACC score                          100.0      100.0   86.621115  86.791933
# ACC score difference                 0.0        0.0   14.116929  13.929027
#
#                                       DP
# Demographic parity difference   1.054034
# ACC score                      82.510469
# ACC score difference           29.761844
